# %% [markdown]
# # Quick Start to Matrix Profile

# %%
from matplotlib import pyplot as plt
import numpy as np
import matrixprofile as mp

# %matplotlib inline

# %%
dataset = mp.datasets.load('motifs-discords-small')
ts = dataset['data']

# %%
ts.shape
# Out:
# (875,)

# %%
plt.figure(figsize=(20,5))
plt.plot(np.arange(len(ts)), ts)
plt.title('Synthetic Time Series')
plt.show()

# %%
profile, figures = mp.analyze(ts)
# Out:
# /home/cdsw/.local/lib/python3.6/site-packages/matrixprofile/visualize.py:433: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# /home/cdsw/.local/lib/python3.6/site-packages/matrixprofile/visualize.py:433: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# /home/cdsw/.local/lib/python3.6/site-packages/matrixprofile/visualize.py:433: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %%
mp_profile = mp.utils.pick_mp(profile, 32)
mp_figures = mp.visualize(mp_profile)

# %%
mp_profile, mp_figures = mp.analyze(ts, windows=32)
# Out:
# /home/cdsw/.local/lib/python3.6/site-packages/matrixprofile/visualize.py:375: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %%
# compute the Pan-MatrixProfile with windows
profile = mp.compute(ts, windows=[32, 64, 128])

# %%
figures = mp.visualize(profile)

# %%
# compute the MatrixProfile
profile = mp.compute(ts, windows=[32])

# %%
figures = mp.visualize(profile)
